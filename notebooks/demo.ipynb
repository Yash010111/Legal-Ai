# %% [markdown]
# # Legal Mind AI Demo
#
# This notebook demonstrates the capabilities of Legal Mind AI for legal document processing and analysis.

# %%
# Import necessary libraries
import sys
import os

# Add src to path
sys.path.append(os.path.join('..', 'src'))

from src.ai_engine import LegalMindAI
from src.text_utils import clean_legal_text, extract_sections, extract_case_citations
